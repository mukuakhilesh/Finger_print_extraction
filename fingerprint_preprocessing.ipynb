# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('finger_2.png')

hsv_blue = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
lw_blue = np.array([0,55,45])
up_blue = np.array([250,160,235])
mask = cv2.inRange(hsv_blue,lw_blue,up_blue)
nw_img = cv2.bitwise_and(img,img,mask=mask)
nw = cv2.cvtColor(nw_img , cv2.COLOR_BGR2RGB)
plt.imshow(nw)
plt.plot()
# Out:
# []

# %%
# import IPython.display
# import PIL
# IPython.display.display(PIL.Image.fromarray(gray))

# %%
gray = cv2.cvtColor(nw , cv2.COLOR_RGB2GRAY)
xy = cv2.equalizeHist(gray)
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(xy,cmap='gray')
plt.plot()
# Out:
# []

# %%
prev = xy
normalizedImg = np.array(xy,dtype='float32')
#normalizedImg = cv2.normalize(img,None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)
plt.subplot(1,2,1)
plt.imshow(xy,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(normalizedImg,cmap='gray')
plt.plot()
np.max(normalizedImg)
# Out:
# 255.0

# %%
prev = cv2.adaptiveThreshold(xy,0.75,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,15,3)
prev2 = cv2.adaptiveThreshold(xy,0.55,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,15,3)
# plt.subplot(2,2,1)
# plt.imshow(xy,cmap='gray')
plt.subplot(1,2,1)
plt.imshow(prev,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(prev2,cmap='gray')
plt.plot()
# Out:
# []
